# %% [markdown]
# ##  Create a program to read a file and:- Count number of words, lines, and characters- Handle file not found error using exception handling

# %%
with open("data.txt", "w") as file:
    file.write("Hello, this is a sample file.\n")
    file.write("It contains multiple lines.\n")
    file.write("We are learning Python file handling.\n")

print("File created successfully!")
# Out:
# File created successfully!

# %%
try:
    # with open("data.txt", "r") as f:
    with open("raw_data.csv", "r") as f:
        # raw data imported from kaggle.com
        text = f.read()

        print("Lines:", len(text.split('\n')))
        print("Words:", len(text.split()))
        print("Characters:", len(text))

except FileNotFoundError:
    print("File not found")
# Out:
# Lines: 12
# Words: 21
# Characters: 360
